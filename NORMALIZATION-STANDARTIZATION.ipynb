# %%
from sklearn.preprocessing import LabelEncoder

 normalizasyon icinde categoric degiskenkere uygulama
1
 preprocessing.LabelEncoder()
scaler =preprocessing.LabelEncoder()
 data['sex']=scaler.fit_transform(data['sex'])


data["sex"] = data["sex"].astype("category")
 data['sex'] =data['sex'].cat.codes
    

Creating dumy variables for categorical variables for modeling
One hot encoding
data= pd.get_dummies(data,columns =['att','att','att'])


##  Creating dummy variables for categorical variables for modeling
df1 =  pd.get_dummies(df, columns = ['JobSatisfaction', 'JobInvolvement', 'EnvironmentSatisfaction','BusinessTravel'],
                      drop_first=True)



 with get_dummies() function
data = pd.get_dummies(data, columns=["sex"])
data.head()




 from sklearn.impute import SimpleImputer
    imp = SimpleImputer(strategy="most_frequent")
    X=imp.fit_transform(df1)
pd.DataFrame(X)




for i in range(len(df['State'])):
    if df['State'].iloc[i]=="New York":
        df['State'].iloc[i]=0
    elif df['State'].iloc[i]=="Florida":
        df['State'].iloc[i]=1
    else:
        df['State'].iloc[i]=2



## mustafa//
# normalization
# just numeric variables
#
preprocessing.normalize(data)
# bir degiskenini degerinin 0-1 araligina donusturmek
preprocessing.normalize(df)

Min-Max donusumu
scaler =preprocessing.MinMaxScaler(feature_range =(10,20))

#varyanslari korundu
scaler.fit_transform(df)


Bianrize donusum
belirli bir degerin altindakilri 0 ustundekilri 1 yap dedigimizde
veri setinin donusturulmesidir. tasimis oldugu bilgiyi etkiler¶
binarizer = preprocessing.Binarizer(threshold =5).fit(df)
binarizer.transform(df)




0-1 donusumu¶
## kategoric degisken sayilara degistiriliyor
df_l['new_sex']=df_l['sex'].cat.codes
df_l.head()



lbe =preprocessing.LabelEncoder()
df_l['new_new_sex']=lbe.fit_transform(df_l['sex'])



1 ve digerleri(0) donusumu
df_l['new_day']=np.where(df_l['day'].str.contains('Sun'),1,0)




multiple class donusum
lbe = preprocessing.LabelEncoder()
df_l['daha_yeni_gun']= lbe.fit_transform(df_l['day'])
df_l.head()

# %%
from sklearn import  preprocessing
##standart sapma 1,ortalama 0 
# degistirmeler anayapimizi degistirmiyor
preprocessing.scale(df)
