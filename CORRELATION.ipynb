# %%
data.corr()
corr= data.corr()
sns.heatmap(corr,
            xticklabels= corr.columns.values,
            yticklabels= corr.columns.values,)



plt.figure(figsize=(10,10))
sns.heatmap(data1.corr(),annot =True,annot_kws={"size":9});


plt.figure(fidsize=(15,15))
corr=data1.corr()
sns.heatmap(corr,square =True)


sns.heatmap(data.corr()):
plt.show()



sns.heatmap(data[["age","sex","sibsp","parch","pclass"]].corr(), annot = True)
plt.show()



#sns.pairplot(data,kind ='reg');

#sns.jointplot(x='age', y = 'survived',data =data,kind ='reg');


#gender not visible above ?why
# because it consists of strings, I need to convert it to numeric value to see it on the heatmap
#data['sex']

# 1. way   Normalizasyon
#data["sex"] = data["sex"].astype("category")
#data['sex']=data['sex'].cat.codes
# 2.way
#scaler=preproccesing.LabelEncoder
#data['sex']=scaler.fit_transform('sex')
# 3.way
data['sex'] =[ 1 if i =='male'else 0 for i in data['sex']]


sns.heatmap(data.corr());
##sns.heatmap(data[["age","sex","sibsp","parch","pclass",]].corr(), annot = True)
plt.show()






k=11
cols =corr.nlargest(k,'SalePrice')['SalePrice'].index
print(cols)
cm = np.corrcoef(data[cols].values.T)
f,ax =plt.subplots(figsize =(14,12))
sns.hearmp(cm,vmax= .8 ,linewidhts=0.01,square =True,annot =True,cmap ='viridis',linecolor ='white',xticklabels =
          cols.values,annot_kws={'size':12},  yticklabels =)





df[['stays_in_week_nights', 'stays_in_weekend_nights']].corr()




boston_X.corr()
boston_X.corr()['CRIM']
abs(boston_X.corr()['CRIM'].nlargest(n=5))




# see the variables with the highest 5 correlations between them
for col in boston.feature_names:
    highest_values=abs(boston_X.corr()[col]).nlargest(n=5)
    print(highest_values)
    #print if value greater than 0.75.
    for index,value in highest_values.items():
        if 1>value >= 0.75:
            print(index,col,'variables are highly correlated: ',value)
